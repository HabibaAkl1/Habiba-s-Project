# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from matplotlip import  pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from matplotlip import  pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlip'

# %%
from matplotlib import  pyplot as plt

# %%
pd.options.display.float_format ='{:,.2f}'.format   #show numbers with 2 floats only

# %%
pd.options.display.max_rows=None   #show max no of rows
pd.options.display.max_columns=None  # show max no of columns

# %%
#Loading data
df=pd.read_cv('all_data.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Loading data
# ----> 2 df=pd.read_cv('all_data.csv')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_cv'

# %%
df=pd.read_csv('all_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_csv('all_data.csv')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_cv('all_data.csv',encoding= 'iso-8859-1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df=pd.read_cv('all_data.csv',encoding= 'iso-8859-1')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_cv'

# %%
df=pd.read_csv('all_data.csv',encoding= 'iso-8859-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df=pd.read_csv('all_data.csv',encoding= 'iso-8859-1')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('all_data.csv',encoding= 'iso-8859-1') # Loading data

# %%
df.head()
# Out:
#    CustomerID FirstName LastName     City  Country        Phone  OrderID  \
# 0       85.00      Paul  Henriot    Reims   France  26.47.15.10     1.00
# 1       85.00      Paul  Henriot    Reims   France  26.47.15.10     1.00
# 2       85.00      Paul  Henriot    Reims   France  26.47.15.10     1.00
# 3       79.00     Karin  Josephs  Münster  Germany  0251-031259     2.00
# 4       79.00     Karin  Josephs  Münster  Germany  0251-031259     2.00
#
#        OrderDate  OrderNumber  TotalAmount  ProductID  \
# 0  7/4/2012 0:00   542,378.00       440.00      11.00
# 1  7/4/2012 0:00   542,378.00       440.00      42.00
# 2  7/4/2012 0:00   542,378.00       440.00      72.00
# 3  7/5/2012 0:00   542,379.00     1,863.40      14.00
# 4  7/5/2012 0:00   542,379.00     1,863.40      51.00
#
#                      ProductName  UnitPrice           Package IsDiscontinued  \
# 0                 Queso Cabrales      21.00         1 kg pkg.          False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2161 entries, 0 to 2160
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      2158 non-null   float64
#  1   FirstName       2158 non-null   object
#  2   LastName        2158 non-null   object
#  3   City            2158 non-null   object
#  4   Country         2158 non-null   object
#  5   Phone           2158 non-null   object
#  6   OrderID         2155 non-null   float64
#  7   OrderDate       2155 non-null   object
#  8   OrderNumber     2155 non-null   float64
#  9   TotalAmount     2155 non-null   float64
#  10  ProductID       2157 non-null   float64
#  11  ProductName     2157 non-null   object
#  12  UnitPrice       2157 non-null   float64
#  13  Package         2157 non-null   object
#  14  IsDiscontinued  2157 non-null   object
#  15  SupplierID      2157 non-null   float64
#  16  CompanyName     2157 non-null   object
# ...

# %%
df.sample(10)  # for random sample of items
# Out:
#       CustomerID  FirstName   LastName            City  Country  \
# 834         4.00     Thomas      Hardy          London       UK
# 1203       62.00      L?cia   Carvalho       Sao Paulo   Brazil
# 1828        4.00     Thomas      Hardy          London       UK
# 800        79.00      Karin    Josephs         Münster  Germany
# 900        66.00   Maurizio     Moroni   Reggio Emilia    Italy
# 916        44.00     Renate    Messner  Frankfurt a.M.  Germany
# 705        63.00      Horst      Kloss       Cunewalde  Germany
# 519         5.00  Christina   Berglund           Lule?   Sweden
# 820        56.00  Henriette  Pfalzheim            K?ln  Germany
# 13         76.00    Pascale   Cartrain       Charleroi  Belgium
#
#                   Phone  OrderID        OrderDate  OrderNumber  TotalAmount  \
# 834      (171) 555-7788   311.00    6/4/2013 0:00   542,688.00     2,142.90
# 1203      (11) 555-1189   457.00  10/14/2013 0:00   542,834.00       595.50
# ...

# %%
#change customer ID data Type from Float to int
#Delete Orders with NaN Values
#Rename city1 ,Country1 ,phone1  
#Change Order Data type into Date

# %%
#Delete Order NaN Values
df[df.OrderID.isnull()]
# Out:
#       CustomerID FirstName  LastName    City Country            Phone  \
# 2155         NaN       NaN       NaN     NaN     NaN              NaN
# 2156         NaN       NaN       NaN     NaN     NaN              NaN
# 2157       92.00       Ali       Ali   Cairo   Egypt                0
# 2158       22.00     Diego      Roel  Madrid   Spain   (91) 555 94 44
# 2159       57.00     Marie  Bertrand   Paris  France  (1) 42.34.22.66
# 2160         NaN       NaN       NaN     NaN     NaN              NaN
#
#       OrderID OrderDate  OrderNumber  TotalAmount  ProductID   ProductName  \
# 2155      NaN       NaN          NaN          NaN      78.00  Stroopwafels
# 2156      NaN       NaN          NaN          NaN      79.00   DataScience
# 2157      NaN       NaN          NaN          NaN        NaN           NaN
# 2158      NaN       NaN          NaN          NaN        NaN           NaN
# 2159      NaN       NaN          NaN          NaN        NaN           NaN
# ...

# %%
df.dropna(subset='OrderID',inplace=True)

# %%
#Rename columns
df.rename(columns={'City.1': 'SuppCity','Country.1':'SuppCountry','Phone.1':'SuppPhone'},inplace=True) #use dictionary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2155 entries, 0 to 2154
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      2155 non-null   float64
#  1   FirstName       2155 non-null   object
#  2   LastName        2155 non-null   object
#  3   City            2155 non-null   object
#  4   Country         2155 non-null   object
#  5   Phone           2155 non-null   object
#  6   OrderID         2155 non-null   float64
#  7   OrderDate       2155 non-null   object
#  8   OrderNumber     2155 non-null   float64
#  9   TotalAmount     2155 non-null   float64
#  10  ProductID       2155 non-null   float64
#  11  ProductName     2155 non-null   object
#  12  UnitPrice       2155 non-null   float64
#  13  Package         2155 non-null   object
#  14  IsDiscontinued  2155 non-null   object
#  15  SupplierID      2155 non-null   float64
#  16  CompanyName     2155 non-null   object
# ...

# %%
df[df.OrderID.isnull()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, FirstName, LastName, City, Country, Phone, OrderID, OrderDate, OrderNumber, TotalAmount, ProductID, ProductName, UnitPrice, Package, IsDiscontinued, SupplierID, CompanyName, ContactName, SuppCity, SuppCountry, SuppPhone, Fax]
# Index: []

# %%
#Change OrderDate dataTYPE
df.OrderDate=pd.to_datetime(df.OrderDate)

# %%
#Change CustomerID data type to int
for cols in df.columns:
    if 'ID' in cols or 'OrderNumber' in cols:
        df[cols]=df[cols].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2155 entries, 0 to 2154
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      2155 non-null   int32
#  1   FirstName       2155 non-null   object
#  2   LastName        2155 non-null   object
#  3   City            2155 non-null   object
#  4   Country         2155 non-null   object
#  5   Phone           2155 non-null   object
#  6   OrderID         2155 non-null   int32
#  7   OrderDate       2155 non-null   datetime64[ns]
#  8   OrderNumber     2155 non-null   int32
#  9   TotalAmount     2155 non-null   float64
#  10  ProductID       2155 non-null   int32
#  11  ProductName     2155 non-null   object
#  12  UnitPrice       2155 non-null   float64
#  13  Package         2155 non-null   object
#  14  IsDiscontinued  2155 non-null   object
#  15  SupplierID      2155 non-null   int32
#  16  CompanyName     2155 non-null   object
# ...
